# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# from Model import check_v4
from check_v4 import Model

# %%
import cv2
im1 = cv2.imread("1.jpg")
im2 = cv2.imread("2.jpg")
im3 = cv2.imread("3.jpg")
im4 = cv2.imread("4.jpg")

# %%
im1.shape
# Out:
# (640, 640, 3)

# %%
# c = Model()

# %%
# c9

# %%
Model.check_yolo(im3)
# Out:
# weights :  C:\Users\Playdata\Desktop\vscod\check\yolov5\f_best.pt
# YOLOv5  v7.0-203-g0897415 Python-3.10.11 torch-2.0.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients
# yolo model load time : 0.4001035690307617
# det :  tensor([[208., 192., 303., 342.],
#         [218.,  99., 269., 145.],
#         [215., 134., 274., 163.]])
# [[[208.0, 192.0, 303.0, 342.0, 0.9354767203330994, 1.0], [218.0, 99.0, 269.0, 145.0, 0.8756706714630127, 3.0], [215.0, 134.0, 274.0, 163.0, 0.7857924699783325, 0.0]]]
# check_yolo result :  [[208.0, 192.0, 303.0, 342.0, 0.9354767203330994, 1.0], [218.0, 99.0, 269.0, 145.0, 0.8756706714630127, 3.0], [215.0, 134.0, 274.0, 163.0, 0.7857924699783325, 0.0]]
# [[208.0, 192.0, 303.0, 342.0, 0.9354767203330994, 1.0],
#  [218.0, 99.0, 269.0, 145.0, 0.8756706714630127, 3.0],
#  [215.0, 134.0, 274.0, 163.0, 0.7857924699783325, 0.0]]

# %%
# YOLOv5  v7.0-203-g0897415 Python-3.10.11 torch-2.0.1+cpu CPU

# Fusing layers... 
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# yolo model load time : 0.22191214561462402
# tensor([[233.00000, 105.00000, 392.00000, 624.00000,   0.86024,   0.00000]])
# [[[233.0, 105.0, 392.0, 624.0, 0.8602432012557983, 0.0]]]
# [[233.0, 105.0, 392.0, 624.0]]

# %%
Model.check_openpose(im3)
# Out:
# foward시간 :  4.4804065227508545
# [(236, 97),
#  (236, 180),
#  (194, 208),
#  (153, 236),
#  (180, 180),
#  (278, 194),
#  (320, 222),
#  (306, 166),
#  (222, 333),
#  (236, 431),
#  (236, 528),
#  (264, 333),
#  (278, 431),
#  (292, 514),
#  (250, 264),
#  (333, 292),
#  None,
#  (236, 153)]

# %%
# [240.0,
#   240.0,
#   208.0,
#   160.0,
#   176.0,
#   280.0,
#   328.0,
#   312.0,
#   232.0,
#   240.0,
#   240.0,
#   272.0,
#   280.0,
#   288.0,
#   248.0],
#  [134.0,
#   184.0,
#   208.0,
#   232.0,
#   184.0,
#   200.0,
#   232.0,
#   184.0,
#   344.0,
#   448.0,
#   528.0,
#   344.0,
#   440.0,
#   528.0,
#   272.0])

# %%
# import time
# protoFile = "pose_deploy_linevec.prototxt" # test111.ipynb에서 test할때
# weightsFile = "pose_iter_160000.caffemodel" #
# # protoFile = "check\pose_deploy_linevec.prototxt" # 0.connect_model에서 runserver할때
# # weightsFile = "check\pose_iter_160000.caffemodel" #

# load_openpose_start = time.time()
# net1 = cv2.dnn.readNetFromCaffe(protoFile, weightsFile) # 0.5
# load_openpose_end = time.time()

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.6.0

# %%
# ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ
Model.calculate(im4)
# Out:
# foward시간 :  4.43117356300354
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 2
#       1 # ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ
# ----> 2 Model.calculate(im4)
#
# File c:\div\Django_tutorial\0.connect_model\check\check_v4.py:286, in Model.calculate(image)
#     284 X,Y = [], []
#     285 # X1,Y1= Model.check_openpose(image)
# --> 286 X,Y= Model.check_openpose(image)
#     288 #368이미지를 openpose로 측정한 좌표를 640이미지에 적용한다.
#     289 # for i in X1:
#     290 #     X.append(round(i/368*640, 0))
#    (...)
#     293 # print("XX : ",X)
#     294 # print("YY : ",Y)
#     296 openpose = time.time()
#
# ValueError: too many values to unpack (expected 2)

# %%
Model.calculate(im3)
# Out:
# YOLOv5  v7.0-203-g0897415 Python-3.10.11 torch-2.0.1+cpu CPU
#
# Fusing layers...
# foward시간 :  4.423741340637207
# weights :  C:\Users\Playdata\Desktop\vscod\check\yolov5\f_best.pt
# Model summary: 157 layers, 7020913 parameters, 0 gradients
# WARNING  --img-size [368, 368] must be multiple of max stride 32, updating to [384, 384]
# yolo model load time : 0.2001817226409912
# det :  tensor([[209., 190., 301., 339.],
#         [219.,  97., 268., 147.],
#         [218., 137., 275., 163.]])
# [[[209.0, 190.0, 301.0, 339.0, 0.9165179133415222, 1.0], [219.0, 97.0, 268.0, 147.0, 0.8898899555206299, 3.0], [218.0, 137.0, 275.0, 163.0, 0.6630405187606812, 0.0]]]
# check_yolo result :  [[209.0, 190.0, 301.0, 339.0, 0.9165179133415222, 1.0], [219.0, 97.0, 268.0, 147.0, 0.8898899555206299, 3.0], [218.0, 137.0, 275.0, 163.0, 0.6630405187606812, 0.0]]
# ...

# %%
# im1
# openpose model load time : 0.7130815982818604
# time test : 33.661091804504395
# 이미지 ID :  44 , H :  80 , W :  80
# weights :  C:\Users\Playdata\Desktop\vscod\check\yolov5\f_best.pt
# YOLOv5  v7.0-203-g0897415 Python-3.10.11 torch-2.0.1+cpu CPU

# Fusing layers... 
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# WARNING  --img-size [334, 334] must be multiple of max stride 32, updating to [352, 352]
# yolo model load time : 0.7699766159057617
# det :  tensor([[269., 171., 383., 385.],
#         [295., 115., 349., 145.]])
# check_yolo result :  [[[269.0, 171.0, 383.0, 385.0, 0.8666052222251892, 1.0], [295.0, 115.0, 349.0, 145.0, 0.6483027935028076, 0.0]]]
# out_X :  [320.0, 312.0, 280.0, 240.0, 264.0, 352.0, 400.0, 368.0, 296.0, 304.0, 312.0, 344.0, 352.0, 352.0, 320.0]
# out_Y :  [126.0, 184.0, 192.0, 240.0, 176.0, 200.0, 232.0, 168.0, 360.0, 480.0, 552.0, 360.0, 472.0, 560.0, 272.0]
# bboxes :  [[[269.0, 171.0, 383.0, 385.0, 0.8666052222251892, 1.0], [295.0, 115.0, 349.0, 145.0, 0.6483027935028076, 0.0]]]
# 계산시작지점
# 0번째 for문
# 1.0
# -----1조끼탐지됨-----
# 1번째 for문
# 0.0
# -----0고글탐지됨-----
# 최종리턴값 :  H : 헬멧없음, 고글/조끼있음
# openpose까지의 시간 : 34.569313049316406
# yolo까지의 시간 : 1.2780909538269043
# 계산까지의 시간 : 0.0

# %%
import numpy as np

bboxes = [190.0, 182.0, 300.0, 338.0]

xmean = np.mean([bboxes[0]/640*368, bboxes[2]/640*368])
ymean = np.mean([bboxes[1]/640*368, bboxes[3]/640*368])

xmean1 = np.mean([bboxes[0], bboxes[2]])/640*368
ymean1 = np.mean([bboxes[1], bboxes[3]])/640*368

print(xmean, ymean)
print(xmean1, ymean1)
# Out:
# 140.875 149.5
# 140.875 149.5

# %%
# im2
# openpose model load time : 0.6005728244781494
# time test : 21.673753023147583
# 이미지 ID :  44 , H :  80 , W :  80
# weights :  C:\Users\Playdata\Desktop\vscod\check\yolov5\f_best.pt
# YOLOv5  v7.0-203-g0897415 Python-3.10.11 torch-2.0.1+cpu CPU

# Fusing layers... 
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# WARNING  --img-size [334, 334] must be multiple of max stride 32, updating to [352, 352]
# yolo model load time : 0.43978357315063477
# det :  tensor([[278.,  66., 338., 128.],
#         [267., 185., 372., 384.]])
# check_yolo result :  [[[278.0, 66.0, 338.0, 128.0, 0.7779898643493652, 3.0], [267.0, 185.0, 372.0, 384.0, 0.7598167061805725, 1.0]]]
# out_X :  [312.0, 312.0, 288.0, 280.0, 288.0, 288.0, 272.0, 272.0, 328.0, 328.0, 312.0, 296.0, 304.0, 312.0, 312.0]
# out_Y :  [198.0, 248.0, 128.0, 168.0, 184.0, 264.0, 256.0, 224.0, 376.0, 440.0, 504.0, 376.0, 432.0, 512.0, 312.0]
# bboxes :  [[[278.0, 66.0, 338.0, 128.0, 0.7779898643493652, 3.0], [267.0, 185.0, 372.0, 384.0, 0.7598167061805725, 1.0]]]
# 계산시작지점
# 0번째 for문
# 3.0
# -----3헬멧탐지됨-----
# 1번째 for문
# 1.0
# 통과
# -----1조끼탐지됨-----
# 최종리턴값 :  G : 고글없음, 헬멧/조끼있음
# openpose까지의 시간 : 22.355249881744385
# yolo까지의 시간 : 0.7301523685455322
# 계산까지의 시간 : 0.004087209701538086

# %%
# im3
# openpose model load time : 1.0280356407165527
# YOLOv5  v7.0-203-g0897415 Python-3.10.11 torch-2.0.1+cpu CPU

# time test : 35.78548192977905
# 이미지 ID :  44 , H :  80 , W :  80
# weights :  C:\Users\Playdata\Desktop\vscod\check\yolov5\f_best.pt
# Fusing layers... 
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# WARNING  --img-size [334, 334] must be multiple of max stride 32, updating to [352, 352]
# yolo model load time : 0.4257791042327881
# det :  tensor([[207., 193., 301., 338.]])
# check_yolo result :  [[[207.0, 193.0, 301.0, 338.0, 0.7857009172439575, 1.0]]]
# out_X :  [456.0, 448.0, 448.0, 440.0, 440.0, 448.0, 192.0, 472.0, 256.0, 240.0, 240.0, 248.0, 464.0, 240.0, 208.0]
# out_Y :  [110.0, 144.0, 136.0, 160.0, 144.0, 136.0, 160.0, 240.0, 480.0, 528.0, 544.0, 480.0, 224.0, 544.0, 176.0]
# bboxes :  [[[207.0, 193.0, 301.0, 338.0, 0.7857009172439575, 1.0]]]
# 계산시작지점
# 0번째 for문
# 1.0
# 통과
# -----1조끼탐지됨-----
# 최종리턴값 :  HG : 헬멧/고글없음, 조끼있음
# openpose까지의 시간 : 36.9267156124115
# yolo까지의 시간 : 0.7120800018310547
# 계산까지의 시간 : 0.0

# %%
#im4
# openpose model load time : 0.5328378677368164
# YOLOv5  v7.0-203-g0897415 Python-3.10.11 torch-2.0.1+cpu CPU

# time test : 20.728058338165283
# 이미지 ID :  44 , H :  80 , W :  80
# weights :  C:\Users\Playdata\Desktop\vscod\check\yolov5\f_best.pt
# Fusing layers... 
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# WARNING  --img-size [334, 334] must be multiple of max stride 32, updating to [352, 352]
# yolo model load time : 0.38466477394104004
# det :  tensor([[193., 187., 297., 350.],
#         [213.,  83., 269., 144.],
#         [223., 131., 285., 160.]])
# check_yolo result :  [[[193.0, 187.0, 297.0, 350.0, 0.9056280255317688, 1.0], [213.0, 83.0, 269.0, 144.0, 0.8122494220733643, 3.0], [223.0, 131.0, 285.0, 160.0, 0.44002625346183777, 0.0]]]
# out_X :  [232.0, 232.0, 224.0, 240.0, 272.0, 224.0, 240.0, 480.0, 240.0, 240.0, 240.0, 248.0, 256.0, 248.0, 240.0]
# out_Y :  [78.0, 168.0, 200.0, 264.0, 216.0, 208.0, 256.0, 240.0, 336.0, 432.0, 560.0, 336.0, 432.0, 552.0, 264.0]
# bboxes :  [[[193.0, 187.0, 297.0, 350.0, 0.9056280255317688, 1.0], [213.0, 83.0, 269.0, 144.0, 0.8122494220733643, 3.0], [223.0, 131.0, 285.0, 160.0, 0.44002625346183777, 0.0]]]
# 계산시작지점
# 0번째 for문
# 1.0
# -----1조끼탐지됨-----
# 1번째 for문
# 3.0
# -----3헬멧탐지됨-----
# 2번째 for문
# 0.0
# -----0고글탐지됨-----
# 최종리턴값 :  N
# openpose까지의 시간 : 21.333740711212158
# yolo까지의 시간 : 0.6598765850067139
# 계산까지의 시간 : 0.0

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import torch
import torchvision
from torchvision import transforms
# %matplotlib inline

resize_trans = transforms.Compose([
    transforms.Resize((368,368)),
    transforms.ToTensor()
])

def myFig(img, label):
    fig, ax = plt.subplots()

    ax.imshow(img)

    if len(label)>0:
        # dw = img.shape[1]|
        # dh = img.shape[0]

        x1 = label[0] #x축 시작점
        y1 = label[1] #y축 시작점
        w = label[2] - label[0] #x축 시작점에서 떨어질 거리
        h = label[3] - label[1] #y축 시작점에서 떨어질 거리

        rect = patches.Rectangle((x1, y1), w, h, linewidth = 1, edgecolor = "r", facecolor = "none")

        ax.add_patch(rect)
    plt.show()

# %%
img = torchvision.datasets.imageFolder(root = "check/3.jpg" , transform = resize_trans)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 img = torchvision.datasets.imageFolder(root = "check/3.jpg" , transform = resize_trans)
#
# File c:\div\Django_tutorial\0.connect_model\.venv1\lib\site-packages\torchvision\datasets\__init__.py:145, in __getattr__(name)
#     141     from torchvision.datapoints._dataset_wrapper import wrap_dataset_for_transforms_v2
#     143     return wrap_dataset_for_transforms_v2
# --> 145 raise AttributeError(f"module {__name__!r} has no attribute {name!r}")
#
# AttributeError: module 'torchvision.datasets' has no attribute 'imageFolder'

# %%
import cv2

# %%
image = cv2.imread("3.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
# box =[210.0, 183.0, 299.0, 351.0]
# box =[222.0, 97.0, 264.0, 150.0]

# box =[208.0, 185.0, 302.0, 346.0] 
# box =[218.0, 99.0, 267.0, 145.0]
# box =[221.0, 130.0, 270.0, 157.0]

# box = [309.0, 241.0, 428.0, 468.0]
# box= [323.0, 103.0, 391.0, 177.0]
# box =[324.0, 164.0, 395.0, 200.0]


# box = [207.0, 193.0, 301.0, 338.0]
# box = [264., 175., 373., 390.]
# box = [275.,  65., 338., 130.]

# box = [208.0, 192.0, 303.0, 342.0]
# box = [218.0, 99.0, 269.0, 145.0]

# box =[208., 192., 303., 342.]
box =   [218.,  99., 269., 145.]
# box = [215., 134., 274., 163.]
box = [189., 188., 299., 335.]
box = [190.0, 182.0, 300.0, 338.0]
box = [189.0, 188.0, 299.0, 335.0]

# 0 : goggle
# 1 : vest
# 2 : head
# 3 : helmet

# %%
myFig(image,box)

# %%
# box = [240, 184, 241, 84]
# # 237.0 / xmax2 :  237.0 / ymin2 :  334.0 / ymax2 :  209.0
# box = [237,334,237,209]
box = [ 237.0 ,  223.0 ,  348.0,  209.0]
box = [140.875, 149.5, 150, 159]
myFig(image,box)

# %%
# box = [190.0 ,290.0 ,84.0 , 84.0]
# box =  [267., 176., 374., 365.]
# box = [273.,  71., 347., 139.]

# box = [271., 184., 381., 382.]
# box = [289., 119., 349., 149.]

# box = [189., 188., 299., 335.]
# box =[207.,  86., 273., 147.]
# box =[218., 133., 280., 161.]
box =  [ 244.0 ,261.5, 255, 272]

myFig(image,box)

# %%
#im3탐지


# openpose model load time : 0.3916165828704834
# YOLOv5  v7.0-203-g0897415 Python-3.10.11 torch-2.0.1+cpu CPU

# 이미지 ID :  44 , H :  80 , W :  80
# Fusing layers... 
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# yolo model load time : 0.35996580123901367
# tensor([[5.78000e+02, 1.52000e+02, 6.40000e+02, 3.22000e+02, 3.52860e-01, 5.80000e+01],
#         [1.63000e+02, 9.70000e+01, 3.14000e+02, 5.74000e+02, 3.26277e-01, 0.00000e+00]])
# 변경전 result :  [[[578.0, 152.0, 640.0, 322.0, 0.3528602421283722, 58.0], [163.0, 97.0, 314.0, 574.0, 0.32627686858177185, 0.0]]]
# 변경후 result :  [[[578.0, 152.0, 640.0, 322.0, 0.3528602421283722, 58.0], [163.0, 97.0, 314.0, 574.0, 0.32627686858177185, 0.0]]]
# len 2
# bboxes :  [[578.0, 152.0, 640.0, 322.0], [163.0, 97.0, 314.0, 574.0]]
# out_X :  [240.0, 184.0, 192.0, 184.0, 208.0, 224.0, 256.0, 472.0, 232.0, 264.0, 240.0, 200.0, 248.0, 240.0, 200.0]
# out_Y :  [104.0, 192.0, 144.0, 168.0, 368.0, 136.0, 336.0, 240.0, 384.0, 456.0, 536.0, 200.0, 464.0, 528.0, 152.0]
# bboxes :  [[578.0, 152.0, 640.0, 322.0], [163.0, 97.0, 314.0, 574.0]]
# 계산시작지점
# xmin :  284.0 xmax :  196.0 ymin :  192.0 ymax :  104.0
# 탐지된 박스의 개수 :  2
# cal bboxes :  4
# bboxes :  [[578.0, 152.0, 640.0, 322.0], [163.0, 97.0, 314.0, 574.0]]
# bboxes[0] :  [578.0, 152.0, 640.0, 322.0]
# xmean :  609.0
# ymean :  237.0
# xmean :  238.5
# ymean :  335.5
# 다시 장비를 착용해주십시오
# openpose까지의 시간 : 20.825450897216797
# yolo까지의 시간 : 0.9556586742401123
# 계산까지의 시간 : 0.0

# %%
import cv2

# %%
cv2.imread("https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyMzA1MjRfODYg%2FMDAxNjg0OTExMzM3OTcz.3ghlmuj29lwX78Xq2SzUXv9J8-xLT9rBXgqAdyfvQtMg.aQLfB1hBSI6xZrmHA8wfLRbQqw03vBBhOahwadvJbjUg.JPEG.bm7928%2FKakaoTalk_Photo_2023-05-24-15-55-17.jpeg%2Fundefined&type=a340")

# %%
#openpose 연습

# %%
import sys
import numpy as np
import cv2

# 모델 & 설정 파일
model = 'pose_iter_160000.caffemodel'
config = 'pose_deploy_linevec.prototxt'

# 포즈 점 개수, 점 연결 개수, 연결 점 번호 쌍
nparts = 18
npairs = 17
pose_pairs = [(1, 2), (2, 3), (3, 4),  # 왼팔
              (1, 5), (5, 6), (6, 7),  # 오른팔
              (1, 8), (8, 9), (9, 10),  # 왼쪽다리
              (1, 11), (11, 12), (12, 13),  # 오른쪽다리
              (1, 0), (0, 14), (14, 16), (0, 15), (15, 17)]  # 얼굴

# 테스트 이미지 파일
img_files = ['C:\div\Django_tutorial\0.connect_model\check\4.jpg', 
            'C:\div\Django_tutorial\0.connect_model\check\3.jpg',
            'C:\div\Django_tutorial\0.connect_model\check\2.jpg']

# 네트워크 생성
net = cv2.dnn.readNet(model, config)

if net.empty():
    print('Net open failed!')
    sys.exit()

for f in img_files:
    img = cv2.imread(f)

    if img is None:
        continue

    # 블롭 생성 & 추론
    blob = cv2.dnn.blobFromImage(img, 1 / 255., (368, 368))
    net.setInput(blob)
    out = net.forward()  # out.shape=(1, 57, 46, 46)

    h, w = img.shape[:2]

    # 검출된 점 추출
    points = []
    for i in range(nparts):
        heatMap = out[0, i, :, :]
        # 최댓값을 conf에 넣어준다.
        _, conf, _, point = cv2.minMaxLoc(heatMap)
        x = int(w * point[0] / out.shape[3])
        y = int(h * point[1] / out.shape[2])

        points.append((x, y) if conf > 0.1 else None)  # heat map threshold=0.1

    # 검출 결과 영상 만들기
    for pair in pose_pairs:
        p1 = points[pair[0]]
        p2 = points[pair[1]]

        if p1 is None or p2 is None:
            continue

        cv2.line(img, p1, p2, (0, 255, 0), 3, cv2.LINE_AA)
        cv2.circle(img, p1, 4, (0, 0, 255), -1, cv2.LINE_AA)
        cv2.circle(img, p2, 4, (0, 0, 255), -1, cv2.LINE_AA)

    # 추론 시간 출력
    t, _ = net.getPerfProfile()
    label = 'Inference time: %.2f ms' % (t * 1000.0 / cv2.getTickFrequency())
    cv2.putText(img, label, (10, 30), cv2.FONT_HERSHEY_SIMPLEX,
                0.7, (0, 0, 255), 1, cv2.LINE_AA)

    cv2.imshow('img', img)
    cv2.waitKey()

cv2.destroyAllWindows()

# %%
#최빈값 구하기

# %%
from collections import Counter

l = ["N","HVG","N", "HV","N","H", "HG", "HG", "N"]
Counter(l)
# Out:
# Counter({'N': 4, 'HG': 2, 'HVG': 1, 'HV': 1, 'H': 1})

# %%
#Counter 클래스의 most_common() 메쏘드는 등장한 횟수를 내림차순으로 정리
cnt = Counter(l)
cnt.most_common()
# Out:
# [('N', 4), ('HG', 2), ('HVG', 1), ('HV', 1), ('H', 1)]

# %%
cnt.most_common()[0]

# %%
cnt.most_common()[0][0]
# Out:
# 'N'

# %%
from collections import Counter

def last_return(l):
    cnt = Counter(l)
    return cnt.most_common()[0][0]

# %%
a = []
a.append("n")
a
# Out:
# ['n']

# %%
a.append("p")
a
# Out:
# ['n', 'p']

# %%
l = ["N","HVG","N", "HV","N","H", "HG", "HG", "N"]
last_return(l)
# Out:
# 'N'

# %%
l =[{"wc" : "아무것도 탐지되지 않았습니다.", "wr":"아무것도 탐지되지 않았습니다."},{"wc" : "아무것도 탐지되지 않았습니다.", "wr":"아무것도 탐지되지 않았습니다."},{"wc" : "아무것도 탐지되지 않았습니다.", "wr":"아무것도 탐지되지 않았습니다."},{"wc" : "H", "wr":"고글,조끼"}]
last_return(l)
#딕셔너리로 counter를 사용할수는 없다. 그럼 무조건 리스트로 받아야한다.

check의 리턴값을 각자 n 이렇게 받고 함수에서 치환하게한다?
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 l =[{"wc" : "아무것도 탐지되지 않았습니다.", "wr":"아무것도 탐지되지 않았습니다."},{"wc" : "아무것도 탐지되지 않았습니다.", "wr":"아무것도 탐지되지 않았습니다."},{"wc" : "아무것도 탐지되지 않았습니다.", "wr":"아무것도 탐지되지 않았습니다."},{"wc" : "H", "wr":"고글,조끼"}]
# ----> 2 last_return(l)
#
# Cell In[8], line 4, in last_return(l)
#       3 def last_return(l):
# ----> 4     cnt = Counter(l)
#       5     return cnt.most_common()[0][0]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\collections\__init__.py:577, in Counter.__init__(self, iterable, **kwds)
#     566 '''Create a new, empty Counter object.  And if given, count elements
#     567 from an input iterable.  Or, initialize the count from another mapping
#     568 of elements to their counts.
#    (...)
#     574
#     575 '''
#     576 super().__init__()
# --> 577 self.update(iterable, **kwds)
#
# ...
